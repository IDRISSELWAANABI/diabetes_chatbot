# %%
# !pip install gradientai --upgrade
# Out:
# Collecting gradientai
#   Downloading gradientai-1.2.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting aenum>=3.1.11 (from gradientai)
#   Downloading aenum-3.1.15-py3-none-any.whl.metadata (3.7 kB)
# Collecting pydantic<2.0.0,>=1.10.5 (from gradientai)
#   Downloading pydantic-1.10.13-cp311-cp311-win_amd64.whl.metadata (150 kB)
#      ---------------------------------------- 0.0/150.9 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/150.9 kB 445.2 kB/s eta 0:00:01
#      --------------- --------------------- 61.4/150.9 kB 656.4 kB/s eta 0:00:01
#      ------------------------------------ - 143.4/150.9 kB 1.1 MB/s eta 0:00:01
#      ------------------------------------ 150.9/150.9 kB 822.8 kB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages (from gradientai) (2.8.2)
# Requirement already satisfied: urllib3>=1.25.3 in c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages (from gradientai) (1.26.18)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages (from pydantic<2.0.0,>=1.10.5->gradientai) (4.6.3)
# Requirement already satisfied: six>=1.5 in c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->gradientai) (1.16.0)
# Downloading gradientai-1.2.0-py3-none-any.whl (166 kB)
#    ---------------------------------------- 0.0/166.3 kB ? eta -:--:--
#    ---------------------------------------  163.8/166.3 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 166.3/166.3 kB 3.4 MB/s eta 0:00:00
# Downloading aenum-3.1.15-py3-none-any.whl (137 kB)
#    ---------------------------------------- 0.0/137.6 kB ? eta -:--:--
#    -------------------------------------- - 133.1/137.6 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 137.6/137.6 kB 2.1 MB/s eta 0:00:00
# Downloading pydantic-1.10.13-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB 7.9 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.1 MB 8.7 MB/s eta 0:00:01
#    --------------- ------------------------ 0.8/2.1 MB 8.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.1 MB 6.8 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 6.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.5/2.1 MB 5.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.5/2.1 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.9/2.1 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 5.4 MB/s eta 0:00:00
# Installing collected packages: aenum, pydantic, gradientai
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.1.1
#     Uninstalling pydantic-2.1.1:
#       Successfully uninstalled pydantic-2.1.1
# Successfully installed aenum-3.1.15 gradientai-1.2.0 pydantic-1.10.13
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\attrs-18.2.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\click_completion-0.5.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\click_didyoumean-0.3.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\click_help_colors-0.9.4-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\colorama-0.4.3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\gql-3.0.0a6-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\gradient_utils-0.5.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\graphql_core-3.1.7-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\halo-0.0.31-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\log_symbols-0.0.14-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\marshmallow-2.21.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\progressbar2-4.3b0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\prometheus_client-0.9.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\pymongo-3.13.0-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\python_utils-3.8.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\pyyaml-5.4.1-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\requests_toolbelt-1.0.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\shellingham-1.5.4-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\spinners-0.0.24-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\terminaltables-3.1.10-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\websocket_client-0.57.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\wheel-0.35.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at c:\users\idriss\appdata\local\programs\python\python311\lib\site-packages\windows_curses-2.3.2-py3.11-win-amd64.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import pickle
import os
os.environ['GRADIENT_ACCESS_TOKEN'] = "CaL0pY8XgmPLC9qGIFZu23fJJm3pXxuE"
os.environ['GRADIENT_WORKSPACE_ID'] = "3af031eb-844e-4c0a-94c0-ef65078c97e9_workspace"

# %%
from gradientai import Gradient

def main():
  with Gradient() as gradient:
      base_model = gradient.get_base_model(base_model_slug="nous-hermes2")

      new_model_adapter = base_model.create_model_adapter(
          name="test model 3"
      )
      while True :
        instruction = input()
        sample_query = f"### Instruction: {instruction}  \n\n### Response:"
        print(f"Asking: {sample_query}")

        # before fine-tuning
        completion = new_model_adapter.complete(query=sample_query, max_generated_token_count=100).generated_output
        print(completion)

      samples = [
      {
        "inputs":"### Instruction: What is diabetes? \n\n### Response: Diabetes is a chronic medical condition characterized by elevated levels of blood glucose, resulting from the body's inability to produce or effectively use insulin."
      },
      {
        "inputs": "### Instruction: Describe the main types of diabetes. \n\n### Response: The main types of diabetes are Type 1 diabetes, Type 2 diabetes, and gestational diabetes. Each type has different causes, risk factors, and management approaches."
      },
      {
        "inputs": "### Instruction: What are the symptoms of diabetes? \n\n### Response: Common symptoms of diabetes include increased thirst, frequent urination, unexplained weight loss, fatigue, blurred vision, and slow wound healing."
      },
      {
        "inputs": "### Instruction: How is diabetes diagnosed? \n\n### Response: Diabetes is typically diagnosed through blood tests that measure the levels of glucose in the blood. The fasting blood sugar test, oral glucose tolerance test, and glycated hemoglobin (HbA1c) tests are commonly used."
      },
      {
        "inputs": "### Instruction: Explain the role of insulin in diabetes. \n\n### Response: Insulin is a hormone produced by the pancreas that regulates blood sugar. In diabetes, there may be insufficient insulin production (Type 1) or ineffective use of insulin by the body (Type 2). Insulin therapy is often used to manage blood glucose levels."
      },
      {
        "inputs": "### Instruction: How is Type 1 diabetes different from Type 2 diabetes? \n\n### Response: Type 1 diabetes is an autoimmune condition where the body attacks and destroys insulin-producing cells. Type 2 diabetes is characterized by insulin resistance and inadequate insulin production. Type 1 usually develops in childhood or adolescence, while Type 2 is more common in adults."
      },
      {
        "inputs": "### Instruction: What are the risk factors for developing diabetes? \n\n### Response: Risk factors for diabetes include family history, obesity, sedentary lifestyle, age, and certain ethnicities. Gestational diabetes during pregnancy can also increase the risk of Type 2 diabetes later in life."
      },
      {
        "inputs": "### Instruction: How is diabetes managed? \n\n### Response: Diabetes management involves lifestyle modifications such as a healthy diet, regular exercise, and monitoring blood sugar levels. Medications, including insulin, may be prescribed. Continuous glucose monitoring and regular medical check-ups are essential for effective diabetes care."
      },
      {
    "inputs": "### Instruction: What are the complications of diabetes? \n\n### Response: Diabetes can lead to various complications, including cardiovascular issues, kidney disease, nerve damage, and eye problems. Proper management is crucial to reduce the risk of these complications."
  },
  {
    "inputs": "### Instruction: Can diabetes be prevented? \n\n### Response: While Type 1 diabetes cannot be prevented, Type 2 diabetes can often be delayed or prevented through a healthy lifestyle. This includes maintaining a balanced diet, regular physical activity, and maintaining a healthy weight."
  },
  {
    "inputs": "### Instruction: Are there dietary restrictions for people with diabetes? \n\n### Response: Individuals with diabetes should follow a well-balanced diet that includes whole grains, fruits, vegetables, lean proteins, and healthy fats. Monitoring carbohydrate intake and controlling portion sizes are also important."
  },
  {
    "inputs": "### Instruction: What is the link between diabetes and heart health? \n\n### Response: Diabetes is a significant risk factor for heart disease. Managing blood sugar levels, cholesterol, and blood pressure is essential for reducing the risk of cardiovascular complications in individuals with diabetes."
  },
  {
    "inputs": "### Instruction: How does exercise impact diabetes management? \n\n### Response: Regular physical activity is beneficial for diabetes management. It helps control blood sugar levels, improves insulin sensitivity, and contributes to overall health. It's important to consult with healthcare professionals to design an appropriate exercise plan."
  },
  {
    "inputs": "### Instruction: What are the long-term effects of diabetes on the body? \n\n### Response: Long-term effects of diabetes may include damage to blood vessels, nerves, and organs. Complications can affect the eyes, kidneys, heart, and extremities. Proper management can minimize the risk of these complications."
  },
  {
    "inputs": "### Instruction: Is gestational diabetes common during pregnancy? \n\n### Response: Gestational diabetes occurs in some pregnant women and increases the risk of Type 2 diabetes later in life. It is important to monitor blood sugar levels during pregnancy and follow healthcare provider recommendations."
  },
  {
    "inputs": "### Instruction: How does stress affect diabetes? \n\n### Response: Stress can impact blood sugar levels in individuals with diabetes. Managing stress through relaxation techniques, mindfulness, and a healthy lifestyle is important for overall well-being and diabetes control."
  },
        {
    "inputs": "### Instruction: What is the role of carbohydrates in diabetes management? \n\n### Response: Carbohydrates affect blood sugar levels, so individuals with diabetes need to monitor their carbohydrate intake. Choosing complex carbohydrates and spreading them throughout the day helps maintain stable blood sugar levels."
  },
  {
    "inputs": "### Instruction: Can diabetes lead to vision problems? \n\n### Response: Yes, diabetes can lead to vision problems, including diabetic retinopathy. Regular eye exams and proper diabetes management are essential to prevent or detect these issues early."
  },
  {
    "inputs": "### Instruction: How does alcohol consumption affect diabetes? \n\n### Response: Moderate alcohol consumption may be acceptable for some individuals with diabetes, but excessive intake can affect blood sugar levels and interfere with medication. It's important to consult with healthcare professionals for personalized advice."
  },
  {
    "inputs": "### Instruction: Are there alternative treatments for diabetes? \n\n### Response: While lifestyle changes, medication, and insulin are common treatments, some individuals explore complementary therapies such as acupuncture or herbal supplements. However, it's crucial to consult with healthcare providers before trying alternative treatments."
  },
  {
    "inputs": "### Instruction: What is the relationship between obesity and Type 2 diabetes? \n\n### Response: Obesity is a significant risk factor for Type 2 diabetes. Maintaining a healthy weight through a balanced diet and regular exercise is crucial for preventing and managing Type 2 diabetes."
  },
  {
    "inputs": "### Instruction: How can family and friends support someone with diabetes? \n\n### Response: Support from family and friends is important for individuals with diabetes. Understanding the condition, encouraging healthy habits, and offering emotional support can contribute to effective diabetes management."
  },
  {
    "inputs": "### Instruction: Can diabetes affect mental health? \n\n### Response: Yes, diabetes can impact mental health. The stress of managing the condition, concerns about complications, and fluctuations in blood sugar levels may contribute to mental health challenges. Seeking support and addressing mental health is an integral part of diabetes care."
  },
  {
    "inputs": "### Instruction: Is there a cure for diabetes? \n\n### Response: Currently, there is no cure for diabetes. However, proper management through lifestyle changes, medication, and insulin therapy can help individuals lead healthy and fulfilling lives with diabetes."
  },

    ]


      # this is where fine-tuning happens
      # num_epochs is the number of times you fine-tune the model
      # more epochs tends to get better results, but you also run the risk of "overfitting"
      # play around with this number to find what works best for you
      num_epochs = 3
      count = 0
      while count < num_epochs:
          print(f"Fine-tuning the model, iteration {count + 1}")
          new_model_adapter.fine_tune(samples=samples)
          count = count + 1

      # # after fine-tuning
      completion = new_model_adapter.complete(query=sample_query, max_generated_token_count=100).generated_output
      print(f"Generated (after fine-tune): {completion}")

      new_model_adapter.delete()


# Assuming 'your_model' is the variable containing your trained model
      # your_model = new_model_adapter

      # #Save the model to a file in pkl format
      # with open('chatbot.pkl', 'wb') as file:
      #     pickle.dump(your_model, file)


if __name__ == "__main__":
    main()
